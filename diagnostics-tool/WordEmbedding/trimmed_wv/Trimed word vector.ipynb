# %%
from nltk.corpus import stopwords
sw = set(stopwords.words('english'))

# %%
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
import numpy as np


def restrict_w2v(w2v, restricted_word_set):
    
    new_vectors = []
    new_vocab = {}
    new_index2entity = []

    for i in range(len(w2v.vocab)):
        
        word = w2v.index2entity[i]
        
        if word in restricted_word_set:
            
            vec = w2v.vectors[i]
            vocab = w2v.vocab[word]
            
            vocab.index = len(new_index2entity)
            new_index2entity.append(word)
            new_vocab[word] = vocab
            new_vectors.append(vec)
            
        
    w2v.vocab = new_vocab
    w2v.vectors = np.vstack(new_vectors)
    w2v.index2entity = new_index2entity
    w2v.index2word = new_index2entity
    # w2v.vectors_norm = None
    

model = Word2Vec.load('../word2vec_models/word2vec_bmc_30.model')
word_vectors = model.wv

sel_word = []

for word, vocab in word_vectors.vocab.items():
    
    if word in sw: continue
    
    if ('UMLS_' in word) and (len(word) == 13):
        sel_word.append(word)
    
    if vocab.count >= 200:
        sel_word.append(word)

sel_word = set(sel_word)

restrict_w2v(word_vectors, sel_word)
word_vectors.save('trimmed_wv.kv')
# Out:
# /home/chaozhang/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /home/chaozhang/.local/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
word_vectors.most_similar('drop', )
# Out:
# [('UMLS_C0085639', 0.6168836951255798),
#  ('reach', 0.6148582696914673),
#  ('decrease', 0.5975610613822937),
#  ('dip', 0.5654827952384949),
#  ('increase', 0.5651909112930298),
#  ('reduction', 0.5589075684547424),
#  ('return', 0.5532367825508118),
#  ('squeeze', 0.5507760047912598),
#  ('again', 0.5421923995018005),
#  ('turn', 0.5415719151496887)]

# %%
import pandas as pd
dic = {}
WM = pd.read_csv('../../WeightMatrix/Dis_Sym_30.csv', index_col=0)
SYMP = WM.columns
for word in sel_word:
    if ('UMLS_' not in word):
        dic[word] = []
        for syn in word_vectors.most_similar(word, topn = 100):
            syn = syn[0]
            if 'UMLS_' in syn:
                syn = syn.strip('UMLS_')
                if syn in SYMP:
                    dic[word].append(syn)

# %%
new_dic = {}
for idx in dic:
    if dic[idx] != []:
        new_dic[idx] = dic[idx][:5]

# %%
new_dic
# Out:
# {'spem': ['C0013362', 'C0085636', 'C0233565'],
#  'smoke': ['C0337672'],
#  'ambulation': ['C0425251', 'C0871754', 'C0231230'],
#  'tetrahydropyridine': ['C0728899'],
#  'cad': ['C0002962'],
#  'amcus': ['C0347938', 'C0338656'],
#  'haz': ['C0041667'],
#  'cpitn': ['C0149758'],
#  'meningothelial': ['C0741302'],
#  'legion': ['C0037580'],
#  'pneumopericardium': ['C0264576',
#   'C0038450',
#   'C0010520',
#   'C0232118',
#   'C0700292'],
#  'myalgic': ['C0015672'],
#  'parotid': ['C0019825', 'C0038990'],
#  'aspirated': ['C0443260'],
#  'reticulated': ['C0241157'],
#  'vrf': ['C0233565'],
#  'wmsi': ['C0520887'],
#  'epistatic': ['C0281825'],
#  'osd': ['C0085636', 'C0026961'],
#  'upstroke': ['C0232201'],
#  'cystourethrography': ['C1313921', 'C0242453'],
#  'multistability': ['C0542044'],
#  'teens': ['C0497406'],
#  'unemployment': ['C0237154'],
#  'urologic': ['C0242453'],
#  'palpebral': ['C0030232'],
#  'macrometastase': ['C0034079'],
#  'nasal': ['C0010200'],
#  'unsafe': ['C0237154'],
#  'modified': ['C0016512'],
#  'collapsibility': ['C0232118',
#   'C0425488',
#   'C0700292',
#   'C0020578',
#   'C0240100'],
#  'dextrocardium': ['C0018800', 'C0264576', 'C0740844', 'C0232267'],
#  'infiltration': ['C0205400', 'C0221198', 'C0038002'],
#  'monospecific': ['C0746619'],
#  'sonogram': ['C0740844', 'C0232257', 'C0006318', 'C0018800'],
#  'hepatopathy': ['C1096646', 'C0020639', 'C0019209', 'C0239981', 'C0019214'],
#  'vew': ['C0859032'],
#  'nonmotor': ['C0233565', 'C0234133', 'C0338656', 'C0040822'],
#  'quit': ['C0438696'],
#  'disorientation': ['C1273573',
#   'C0872410',
#   'C0085628',
#   'C0233844',
#   'C0030554'],
#  'metastase': ['C0221198', 'C0034079'],
#  'audiologist': ['C0034880'],
#  'workload': ['C0392674'],
#  'dialytic': ['C0020625', 'C0239981'],
#  'cerebral': ['C0347938'],
#  'suprathreshold': ['C0231530'],
#  'rmsf': ['C0429562'],
#  'benzamidine': ['C0234238'],
#  'cud': ['C0013132'],
#  'oﬂ': ['C0859032'],
#  'epiphenomenon': ['C0240805', 'C0234544'],
#  'lloydr': ['C0085606', 'C0231872'],
#  'homeless': ['C0237154', 'C0438696'],
#  'scoliosis': ['C0024031'],
#  'spindled': ['C0741302'],
#  'nsr': ['C0232201'],
#  'alosetron': ['C1291077', 'C0600142'],
#  'hoehn': ['C0233565', 'C0234133'],
#  'throw': ['C0085639'],
#  'shaker': ['C0085631'],
#  'narrate': ['C0558261'],
#  'anamnesis': ['C0235710', 'C0149758', 'C0240962', 'C0151315', 'C0018965'],
#  'neoplastic': ['C0741302'],
#  'aix': ['C0006318'],
#  'disabilities': ['C0233844'],
#  'hypertension': ['C0020649', 'C0002962', 'C0020621'],
#  'spontaneous': ['C0036572', 'C0037763'],
#  'immediately': ['C0424092'],
#  'flu': ['C0010200', 'C0848340'],
#  'dysmetrium': ['C0872410', 'C0013362', 'C0030552', 'C0233844', 'C1273573'],
#  'sedate': ['C0522224'],
#  'hrt': ['C0239301', 'C0600142'],
#  'nucleocapsid': ['C0016927'],
#  'aerosolised': ['C1260880'],
#  'potentials': ['C0231530'],
#  'sutured': ['C0008767'],
#  'precancer': ['C0741302'],
#  'phonatory': ['C0038450', 'C0019825', 'C0040264', 'C0013132', 'C0013362'],
#  'proliferationcancer': ['C1269955'],
#  'actthe': ['C0205254'],
#  'agingclin': ['C0338656'],
#  'agerelated': ['C0338656'],
#  'bjog': ['C0006157'],
#  'discography': ['C0036396', 'C0024031'],
#  'blemish': ['C0085624', 'C0948786'],
#  'course': ['C1517205'],
#  'handj': ['C0018862'],
#  'lumpy': ['C0038999', 'C0241157', 'C0332575', 'C0311395', 'C0332573'],
#  'cardioversion': ['C0232201'],
#  'certolizumab': ['C1517205'],
#  'cect': ['C0034079'],
#  'prehospital': ['C0578150'],
#  'danforth': ['C0554980'],
#  'disorders': ['C0007398', 'C0234133'],
#  'tapping': ['C0233844'],
#  'recessive': ['C0004134'],
#  'mci': ['C0347938', 'C0338656'],
#  'put': ['C0085639'],
#  'parakeratosis': ['C0241157'],
#  'gefitinibn': ['C0034880'],
#  'schlaggarb': ['C0085606'],
#  'melanophage': ['C0241157', 'C0332573', 'C0741302'],
#  'syncopal': ['C0039070', 'C0235710', 'C0312422', 'C0220870', 'C0028084'],
#  'tetraplegium': ['C0522224', 'C0030552'],
#  'azoor': ['C0085635'],
#  'wiggins': ['C0554980'],
#  'subcarinal': ['C0034079', 'C0740844', 'C0264576'],
#  'undetectable': ['C0231221'],
#  'hyperplastic': ['C0741302'],
#  'hypercortisolism': ['C0019572', 'C0032617'],
#  'tant': ['C0235129'],
#  'encephalomalacium': ['C0347938', 'C0221198'],
#  'telegraph': ['C0312422'],
#  'pathology': ['C0221198'],
#  'low': ['C0085639'],
#  'vmean': ['C0149746', 'C0020578'],
#  'calm': ['C0234450', 'C0847488', 'C0541992', 'C0028084', 'C0027769'],
#  'fibrin': ['C0241158'],
#  'actigraphic': ['C0751229', 'C0037384'],
#  'mpmv': ['C0016927'],
#  'mri': ['C0221198'],
#  'lvef': ['C0232201'],
#  'noncognitive': ['C0338656', 'C0424337'],
#  'affliction': ['C0742985'],
#  'emphysematous': ['C0743482', 'C1313921', 'C0264576', 'C0740844'],
#  'aecg': ['C0520886', 'C0520887'],
#  'presenile': ['C0234133'],
#  'carboxylesterase': ['C0234238'],
#  'extention': ['C0277845'],
#  'rehabilitate': ['C0425251'],
#  'motor': ['C0233565'],
#  'skeletonized': ['C0241158'],
#  'normochromic': ['C0038002', 'C0019214', 'C0085702', 'C0019209', 'C0030232'],
#  'trigeminal': ['C0392699'],
#  'fibrocartilage': ['C0241158'],
#  'autonomic': ['C0015672', 'C0149746', 'C0039070', 'C0428977', 'C0020578'],
#  'achalasium': ['C1321756', 'C0014394', 'C0242453'],
#  'treatment': ['C1517205'],
#  'mechanobiology': ['C0427008'],
#  'electromyographic': ['C0231530'],
#  'surprised': ['C0847488', 'C0558261'],
#  'blepharoptosis': ['C0026961', 'C0030552'],
#  'perceptible': ['C0332575', 'C0541911'],
#  'wander': ['C0234450', 'C0020175'],
#  'pulmonary': ['C0013404', 'C0700292', 'C0232118'],
#  'acidotic': ['C0020639', 'C0020440', 'C0028961', 'C0020625', 'C0700292'],
#  'abstinence': ['C0438696'],
#  'hypobaric': ['C0020440', 'C0020578', 'C0700292', 'C0149746', 'C0235396'],
#  'sdnn': ['C0520887'],
#  'microtrauma': ['C0008767', 'C0231530'],
#  'bullous': ['C0041834'],
#  'fibromyalgium': ['C0015672', 'C0030193', 'C0024031', 'C0036396'],
#  'bispeciﬁc': ['C0746619'],
#  'nium': ['C0234133'],
#  'erratically': ['C0234450'],
#  'brachydactyly': ['C0018862'],
#  'hyperdensity': ['C0018800', 'C0740844', 'C0347938'],
#  'pgrna': ['C0016927'],
#  'consumption': ['C0043094', 'C0205254', 'C0020175'],
#  'conivaptan': ['C0020625', 'C0020461'],
#  'mopc': ['C0746619'],
#  'aider': ['C0028084'],
#  'celex': ['C0233647'],
#  'epicondylitis': ['C0036396', 'C0024031'],
#  'hemianopsium': ['C0030552', 'C0013362', 'C1273573', 'C0018991', 'C0030554'],
#  'contused': ['C0241158'],
#  'overlie': ['C0205400'],
#  'concentric': ['C0205400'],
#  'isovolemic': ['C0020440', 'C0700292', 'C0028961'],
#  'cathartic': ['C0016204', 'C0009806'],
#  'prestwich': ['C0554980'],
#  'brugada': ['C0520886', 'C0039070', 'C0232201'],
#  'aggregability': ['C0149746'],
#  'odell': ['C0554980'],
#  'urti': ['C0043144', 'C0011991', 'C0010200'],
#  'masson': ['C0948786'],
#  'manometry': ['C0232602'],
#  'myoplasmic': ['C0235396'],
#  'nssa': ['C0016927'],
#  'mabp': ['C0020440'],
#  'victimization': ['C0438696'],
#  'puff': ['C0037383'],
#  'dislike': ['C0847488', 'C0233481'],
#  'nonepileptic': ['C0036572', 'C0438696'],
#  'hematogenously': ['C1313921'],
#  'ifa': ['C0427629'],
#  'tonometric': ['C0232118'],
#  'dysthymium': ['C0022107'],
#  'prepulse': ['C0040264', 'C0034880'],
#  'urination': ['C0232726', 'C0013428', 'C0009806', 'C1291077', 'C0917801'],
#  'cognitively': ['C0338656', 'C0871754'],
#  'granulocytic': ['C0085702'],
#  'mcav': ['C0149746', 'C0020578', 'C0020440'],
#  'raloxifene': ['C0239301'],
#  'ld': ['C0281825'],
#  'rise': ['C0085639'],
#  'recreational': ['C0205254'],
#  'unsuccessful': ['C0424092'],
#  'irritant': ['C0677500', 'C0085624', 'C0037383'],
#  'pnx': ['C0743482'],
#  'oxytocic': ['C0006157'],
#  'dfsp': ['C0741302'],
#  'immunosuppression': ['C0241526'],
#  'ﬂushing': ['C0016382'],
#  'neurostimulation': ['C0040264', 'C0231530'],
#  'flute': ['C0859032'],
#  'fussiness': ['C0233844', 'C0576456', 'C0235198', 'C0232602', 'C0013144'],
#  'delivew': ['C0006157', 'C0860096', 'C0156543'],
#  'beige': ['C0332573'],
#  'arrhythmogenesis': ['C0232201'],
#  'atency': ['C0231530'],
#  'tremble': ['C0027769', 'C0872410', 'C0220870', 'C0008301', 'C0917801'],
#  'claudius': ['C0221232'],
#  'phonemic': ['C0233647'],
#  'hypopnoea': ['C0037384', 'C0425488', 'C0751229', 'C0700292', 'C0020578'],
#  'unremarkable': ['C0277797', 'C0000731', 'C0030232', 'C0232498', 'C0240962'],
#  'regurgitate': ['C0037383', 'C0008301'],
#  'blow': ['C0008301'],
#  'bicarbonate': ['C0020461', 'C0020625', 'C0020621', 'C0235396'],
#  'height': ['C0497406', 'C0427008'],
#  'boyfriend': ['C0558261'],
#  'urinalysis': ['C0277797', 'C0240962', 'C0018965', 'C0277977', 'C0020639'],
#  'numbing': ['C0028084'],
#  'dehiscence': ['C0008767', 'C0013491'],
#  'gelding': ['C0311395'],
#  'sympathovagal': ['C0149746', 'C0020578'],
#  'desperation': ['C0847488'],
#  'pronounce': ['C0541911', 'C0234450'],
#  'high': ['C0085639'],
#  'perineural': ['C0221198'],
#  'nephro': ['C0020625'],
#  'cardiopulmonary': ['C0578150',
#   'C0700292',
#   'C0020578',
#   'C0425488',
#   'C0039070'],
#  'trigram': ['C0233647'],
#  'asphyxiation': ['C0008301'],
#  'stunt': ['C0041667', 'C0019214', 'C0576456', 'C0019209', 'C0497406'],
#  'corroborative': ['C0034642'],
#  'affirmative': ['C0232517'],
#  'disarrangement': ['C0205400'],
#  'gerontology': ['C0871754', 'C0338656'],
#  'wbct': ['C0578150', 'C0149746'],
#  'insidious': ['C0037580', 'C0019214', 'C0240805', 'C0007398', 'C0003862'],
#  'ptca': ['C0002962'],
#  'phrenic': ['C0231530'],
#  'shmollus': ['C0520887'],
#  'illicit': ['C0237154', 'C0438696'],
#  'whee': ['C0859032'],
#  'crust': ['C0241157'],
#  'alphanumeric': ['C0233647'],
#  'agranulocytosis': ['C0559546', 'C1096646'],
#  'motogenic': ['C1269955'],
#  'caretaker': ['C0237304'],
#  'sociometric': ['C0578859'],
#  'temperament': ['C0022107'],
#  'dermatopathologist': ['C0741302'],
#  'medcrimcase': ['C0003862', 'C0019214', 'C0018965', 'C0019209'],
#  'vlcd': ['C0043094'],
#  'undercooked': ['C0037383'],
#  'digitus': ['C0231530'],
#  'lucid': ['C0234450'],
#  'corticobasal': ['C0234133', 'C0233565'],
#  'presentation': ['C0221198'],
#  'monosymptomatic': ['C0014394',
#   'C0234133',
#   'C1321756',
#   'C0042571',
#   'C0034880'],
#  'ctnt': ['C0520887', 'C0520886'],
#  'sufferer': ['C0742985', 'C0917801', 'C0018681', 'C0233481'],
#  'escalator': ['C0085639', 'C0008301'],
#  'passive': ['C0037383'],
#  'cfigure': ['C0085606'],
#  'disgusted': ['C0847488'],
#  'exerciseeur': ['C0149746', 'C0392674'],
#  'dyskinesia': ['C0040822', 'C0233565', 'C0234133', 'C0036572', 'C0392699'],
#  'medarmannals': ['C0030554', 'C0857516', 'C0028643', 'C0872410'],
#  'rvsp': ['C0232118', 'C0700292', 'C0020440', 'C0020578'],
#  'neuralgia': ['C0036396', 'C0018681', 'C0042571', 'C0392699', 'C0423571'],
#  'silly': ['C0558261'],
#  'pedi': ['C0013491'],
#  'infiltrating': ['C0741302'],
#  'diaphragmatic': ['C0264576', 'C0038450'],
#  'jidojindian': ['C0038999', 'C0019214'],
#  'episode': ['C0018681', 'C0036572', 'C0042963', 'C0010200', 'C0011991'],
#  'iild': ['C0338656'],
#  'mcdonough': ['C0554980'],
#  'immunoexpression': ['C0741302'],
#  'buffering': ['C0235396'],
#  'pericardium': ['C0241158'],
#  'mcnamara': ['C0554980'],
#  'tocolysis': ['C0006157'],
#  'hypometabolic': ['C0347938', 'C0041657'],
#  'sleep': ['C0751229', 'C0015672', 'C0037384', 'C0234450', 'C0917801'],
#  'loudly': ['C0558261', 'C0859032', 'C0008301', 'C0232517'],
#  'brunnstrom': ['C0233565', 'C0030552'],
#  'hemicranium': ['C0018681', 'C0236018', 'C0042571', 'C0040264', 'C0037763'],
#  'ophthalmological': ['C0026961'],
#  'retraction': ['C0205400', 'C0008767'],
#  'diquafosol': ['C0026961'],
#  'nms': ['C0020625', 'C0007398'],
#  'kjae': ['C0020649'],
#  'pupillary': ['C0026961'],
#  'hypercoagulability': ['C0085702'],
#  'cavi': ['C0427008'],
#  'wounded': ['C0241158'],
#  'zoster': ['C0036396'],
#  'likert': ['C0847488', 'C0233481'],
#  'blinking': ['C0013144'],
#  'hyperpyrexium': ['C0231835', 'C0151315', 'C0085628', 'C0010520', 'C0028961'],
#  'expressivity': ['C0424230', 'C0034880'],
#  'chyle': ['C1313921'],
#  'yahr': ['C0233565', 'C0234133', 'C0425251'],
#  'qiaamp': ['C0744492'],
#  'slowing': ['C0231530'],
#  'accidentally': ['C0008301'],
#  'emmprin': ['C1269955'],
#  'flattening': ['C0205400'],
#  'blood': ['C0020649'],
#  'iah': ['C0700292', 'C0578150', 'C0020440', 'C0020649', 'C0231187'],
#  'shimmer': ['C0019825'],
#  'cochlear': ['C0040264'],
#  'nonaerated': ['C0264576', 'C0743482'],
#  'aprv': ['C0020440', 'C0700292', 'C0020578', 'C0425488'],
#  'oropharyngeal': ['C0019825'],
#  'colloquial': ['C0233647'],
#  'grief': ['C0233481'],
#  'nccp': ['C0018834', 'C1321756', 'C0235710', 'C0039070', 'C0086439'],
#  'haemodynamically': ['C0578150',
#   'C0002962',
#   'C0700292',
#   'C0232118',
#   'C0232201'],
#  'overinflation': ['C0264576', 'C0743482', 'C0232118', 'C0700292', 'C0035508'],
#  'spend': ['C0205254'],
#  'elastic': ['C0427008'],
#  'avoidance': ['C0030318'],
#  'pretend': ['C0558261'],
#  'salpingectomy': ['C0006157'],
#  'counterweight': ['C0497406'],
#  'watts': ['C0554980'],
#  'incapability': ['C1299586', 'C0030552', 'C0241526'],
#  'postmenopausal': ['C0600142', 'C0239301'],
#  'resuscitate': ['C0578150'],
#  'pilocarpine': ['C0036572'],
#  'willpower': ['C0233481'],
#  'stillborn': ['C0156543', 'C0006157'],
#  'cimt': ['C0427008'],
#  'pregsure': ['C0427629'],
#  'bore': ['C0558261', 'C0847488'],
#  'nasally': ['C1260880'],
#  'lipoatrophy': ['C0019572'],
#  'bruise': ['C0013491', 'C0332575', 'C0038999', 'C0085624', 'C0041834'],
#  'gozal': ['C0751229', 'C0338656'],
#  'conjunctiva': ['C0332575', 'C0041834'],
#  'mantoux': ['C0032739'],
#  'inph': ['C0347938'],
#  'wingbeat': ['C0231530'],
#  'daan': ['C0242429'],
#  'bility': ['C0281825'],
#  'repe': ['C0038450', 'C0264576', 'C0019079', 'C0232118'],
#  'chondral': ['C0241158'],
#  'question': ['C1299586'],
#  'refixation': ['C0277845'],
#  'surgcrim': ['C0085606'],
#  'proven': ['C0231221'],
#  'technical': ['C1299586'],
#  'vvbc': ['C0085702', 'C0239981'],
#  'urolithiasis': ['C0242453', 'C0014394', 'C0020625'],
#  'category': ['C0085639'],
#  'amnestic': ['C0338656', 'C0347938', 'C0234133'],
#  'hypokinetic': ['C0233565', 'C0872410', 'C0234133', 'C0030552', 'C0009024'],
#  'etiopathology': ['C0240805'],
#  'frusemide': ['C0020461'],
#  'nipd': ['C0427629'],
#  'tactile': ['C0040264'],
#  'nominalization': ['C0233647'],
#  'antihistamine': ['C0559546'],
#  'merle': ['C0311395', 'C0018862'],
#  'cmep': ['C0231530'],
#  'ndma': ['C0728899'],
#  'emphysema': ['C0743482', 'C0264576', 'C0013404', 'C0700292', 'C0035508'],
#  'espghan': ['C0149696'],
#  'bronchiectatic': ['C0743482', 'C0035508'],
#  'thrashing': ['C0242143', 'C0522224', 'C0231441', 'C0008301'],
#  'vulvodynium': ['C1384606', 'C0423571', 'C0600142', 'C0392699', 'C0235250'],
#  'friedreich': ['C0004134'],
#  'immunosupression': ['C1096646'],
#  'angiogenetic': ['C1269955'],
#  'needling': ['C0423571', 'C0677500', 'C0030193'],
#  'deﬂection': ['C0231530'],
#  'exudation': ['C0443260', 'C0241157', 'C0205400'],
#  'brompton': ['C0240100', 'C0085619', 'C0034642'],
#  'missense': ['C0004134'],
#  'eczematous': ['C0041834', 'C0241157', 'C0085624', 'C0033774', 'C0332573'],
#  'giant': ['C0038999'],
#  'poison': ['C0728899'],
#  'prolapsed': ['C1384606', 'C0008767'],
#  'fot': ['C0425488', 'C0232118', 'C0020578'],
#  'depressor': ['C0231530'],
#  'ibutilide': ['C0232201'],
#  'functioning': ['C0338656', 'C0233467', 'C0015672'],
#  'rvi': ['C0020440', 'C0020578', 'C0700292', 'C0020625'],
#  'lsbl': ['C0281825'],
#  'hemoptysis': ['C0019079', 'C0013404', 'C0038450', 'C0008033', 'C0019825'],
#  'reheat': ['C0085593'],
#  'didanosine': ['C1096646'],
#  'tonebp': ['C0235396'],
#  'archives': ['C0233647', 'C0037384'],
#  'insecurity': ['C0020175', 'C0237154', 'C0233481'],
#  'kmi': ['C0600142'],
#  'mildly': ['C0030232', 'C0205400', 'C0040822', 'C0231221', 'C0232498'],
#  'dermatitis': ['C0033774', 'C0041834'],
#  'anc': ['C0860096'],
#  'digitali': ['C0020461'],
#  'reintubation': ['C0700292'],
#  'bloodspot': ['C0427629'],
#  'esr': ['C0003862', 'C0277797', 'C1517205'],
#  'matricellular': ['C1269955'],
#  'deren': ['C0221232'],
#  'fcdt': ['C0026961'],
#  'caloric': ['C0043094', 'C0020175'],
#  'nullipara': ['C0860096', 'C0006157'],
#  'bepotastine': ['C0026961'],
#  'myelitis': ['C0030552'],
#  'comedone': ['C0241157', 'C0085624', 'C0033774', 'C0677500'],
#  'geotaxi': ['C0242143', 'C0277977'],
#  'rehabilitation': ['C0871754', 'C0024031', 'C0030193'],
#  'osmolar': ['C0020461', 'C0020625'],
#  'macroscopically': ['C0241158', 'C0221198'],
#  'everybody': ['C0558261'],
#  'macerate': ['C0085593'],
#  'positive': ['C0032739', 'C0277977', 'C0427629'],
#  'ofjoint': ['C0018862'],
#  'neuroenergetic': ['C0347938'],
#  'trabecula': ['C0241158'],
#  'phlebotomy': ['C0020639'],
#  'concussive': ['C0312422'],
#  'hemoglobin': ['C0239981', 'C0240962', 'C0020639'],
#  'beitrag': ['C0221232'],
#  'tierarztl': ['C0311395'],
#  'basaloid': ['C0741302'],
#  'osmolality': ['C0020625', 'C0235396', 'C0032617', 'C0020461'],
#  'bleeding': ['C0019080', 'C0020649', 'C0042963', 'C0027497', 'C0016382'],
#  'reintubate': ['C0578150', 'C0038450', 'C0700292', 'C0020578'],
#  'ostomy': ['C1384606'],
#  'epithelialmesenchymal': ['C1269955'],
#  'behaviourj': ['C0424337'],
#  'oaus': ['C0018862'],
#  'dexterity': ['C0233844', 'C0231230'],
#  'childbirth': ['C0156543', 'C0006157'],
#  'cervicitis': ['C1384606'],
#  'beloved': ['C0558261'],
#  'polyphagium': ['C0032617', 'C0023380', 'C0016204', 'C0232726', 'C0003123'],
#  'discontinuation': ['C0559546',
#   'C1517205',
#   'C0424092',
#   'C0231187',
#   'C1096646'],
#  'determiner': ['C0233647'],
#  'decliner': ['C0233467'],
#  'chemoinvasion': ['C1269955'],
#  'living': ['C0425251', 'C0231441', 'C0205254'],
#  'vasoconstrictive': ['C0149746'],
#  'antiepileptic': ['C0036572'],
#  'whr': ['C0497406'],
#  'chenoweth': ['C0554980'],
#  'uap': ['C0002962'],
#  'nonepithelial': ['C0741302'],
#  'naevus': ['C0332573'],
#  'druginduced': ['C1096646'],
#  'higgs': ['C0554980'],
#  'ascariasis': ['C0011991'],
#  'institutionalized': ['C0871754', 'C0338656'],
#  'unfilled': ['C0577979'],
#  'overtrain': ['C0392674'],
#  'recumbent': ['C0872410'],
#  'slight': ['C0541911', 'C0205400'],
#  'television': ['C0205254'],
#  'thermode': ['C0423571'],
#  'bva': ['C0003862'],
#  'darkening': ['C0443260', 'C0085624', 'C0030232', 'C0038999', 'C0948786'],
#  'preinjury': ['C0425251'],
#  'aki': ['C0020625', 'C0020461', 'C0231187', 'C0028961', 'C0239981'],
#  'calving': ['C0311395'],
#  'premorbid': ['C0338656'],
#  'beware': ['C0558261'],
#  'apoplexy': ['C0019080'],
#  'forceful': ['C0872410', 'C0008301', 'C0009024', 'C0231530', 'C0037383'],
#  'hfd': ['C0043094'],
#  'coeliac': ['C0149696'],
#  'necrotize': ['C0019080'],
#  'mho': ['C0497406'],
#  'electroencephalogram': ['C0041657',
#   'C0036572',
#   'C0040822',
#   'C0013144',
#   'C0234544'],
#  'dampness': ['C0043144'],
#  'dka': ['C0020461', 'C0020621', 'C0020625', 'C0032617', 'C0231187'],
#  'angiostatin': ['C1269955'],
#  'nonresponsiveness': ['C0241526'],
#  'melanotic': ['C0443260', 'C0038999', 'C0241157', 'C0332573'],
#  'ciocalteu': ['C0424000'],
#  'samm': ['C0860096', 'C0006157'],
#  'unremitting': ['C0392699', 'C0742985', 'C0018681', 'C0423571', 'C0030554'],
#  'dysphagic': ['C0013132', 'C0338656', 'C0233565'],
#  'stupid': ['C0558261', 'C0847488'],
#  'botulinum': ['C0392699'],
#  'extrathoracic': ['C0034079'],
#  'dilate': ['C0205400', 'C0264576', 'C0740844'],
#  'nonconvulsive': ['C0036572', 'C0234544', 'C0085628', 'C0234133', 'C0007398'],
#  'teeth': ['C0149758'],
#  'henle': ['C0032617'],
#  'spiegelmanb': ['C0085606'],
#  'skeletonization': ['C0241158'],
#  'bjsm': ['C0024031'],
#  'dyspareunium': ['C1384606', 'C0600142', 'C0013428', 'C0232726', 'C1291077'],
#  'frequent': ['C0027497', 'C0011991', 'C0012833'],
#  'galvanic': ['C0231530'],
#  'tractj': ['C0242453'],
#  'heave': ['C0541911', 'C0030252', 'C0034642', 'C0037383', 'C0232498'],
#  'warmblood': ['C0311395'],
#  'interval': ['C0085639'],
#  'fleeting': ['C0028084'],
#  'maculopapular': ['C0041834', 'C0332573', 'C0241157', 'C0392699', 'C0013491'],
#  'hypersecretion': ['C0032617', 'C0020621', 'C0241526', 'C0016382'],
#  'angiopathy': ['C0019080'],
#  'sudden': ['C0039070', 'C0312422', 'C0030252', 'C0020649', 'C0037763'],
#  'occurance': ['C0232602', 'C0149758', 'C0232726', 'C0016204', 'C0559546'],
#  'watching': ['C0205254'],
#  'fistulous': ['C1313921'],
#  'drunkenness': ['C0312422', 'C0438696', 'C0237154'],
#  'clotted': ['C0443260'],
#  'vasoreactivity': ['C0149746'],
#  'epilepticus': ['C0036572'],
#  'mvm': ['C0016927'],
#  'intake': ['C0043094', 'C0020175', 'C0497406', 'C0205254'],
#  'aenv': ['C0016927'],
#  'bun': ['C0239981', 'C0028961', 'C0020639', 'C0018965', 'C0240962'],
#  'turning': ['C0872410'],
#  'frostbite': ['C0013491'],
#  'dyspraxium': ['C0233844', 'C0013362', 'C1273573', 'C0004134', 'C0234133'],
#  'complain': ['C0028643', 'C0392680', 'C0030252', 'C0231218', 'C0012833'],
#  'veak': ['C0554980'],
#  'bronchiolitis': ['C0038450', 'C0043144'],
#  'acupuncture': ['C0030193', 'C0423571', 'C0040264', 'C0036396'],
#  'atelectasis': ['C0264576', 'C0700292', 'C0743482', 'C0038450', 'C0035508'],
#  'arousal': ['C0020175'],
#  'ventriculogram': ['C0018800',
#   'C0520886',
#   'C0232201',
#   'C0232267',
#   'C0232257'],
#  'shit': ['C0234450', 'C0859032', 'C0558261'],
#  'vlbwi': ['C0576456'],
#  'confl': ['C0237154'],
#  'haematemesis': ['C0232726', 'C0018932', 'C0018965', 'C0019079', 'C1291077'],
#  'fibrovascular': ['C0741302'],
#  'puv': ['C0014394', 'C0242453'],
#  'ckmb': ['C0520887', 'C0520886'],
#  'complexity': ['C1299586'],
#  'pelvicalyceal': ['C1313921'],
#  'scab': ['C0241157'],
#  'electrographic': ['C0036572'],
#  'wearer': ['C0013132'],
#  'nidcd': ['C0234133', 'C0013362'],
#  'aminotransferase': ['C0239981', 'C1096646', 'C0231528', 'C0019209'],
#  'fv': ['C0016927'],
#  'hypocellularity': ['C0241158', 'C0741302'],
#  'undamaged': ['C0241158'],
#  'decline': ['C0085639', 'C0392674'],
#  'thawing': ['C0085593'],
#  'periodic': ['C0542044'],
#  'albumin': ['C0239981', 'C0020639'],
#  'fibrillation': ['C0039070', 'C0002962'],
#  'capability': ['C1299586'],
#  'microcirculatory': ['C0700292'],
#  'porokeratosis': ['C0332573'],
#  'impend': ['C0008301', 'C0028961', 'C0039070', 'C0857256'],
#  'exclusion': ['C0424092'],
#  'formulaic': ['C0233647'],
#  'smoker': ['C0337672', 'C0205254', 'C0497406'],
#  'primiparity': ['C0860096', 'C0006157'],
#  'septoplasty': ['C0026961'],
#  'necrose': ['C0008767'],
#  'hypercalcaemia': ['C0020621',
#   'C0020461',
#   'C0020625',
#   'C0020639',
#   'C0239981'],
#  'hyalinosis': ['C0205400'],
#  'mpd': ['C0038002'],
#  'praxis': ['C0233647'],
#  'ypm': ['C0497406', 'C0205254'],
#  'bpobgyn': ['C0006157'],
#  'anger': ['C0233492', 'C0233481', 'C0027769'],
#  'intestina': ['C0018932', 'C0009806', 'C0232726', 'C0016204', 'C0011991'],
#  'diagnosable': ['C0007398'],
#  'emaciation': ['C0023380', 'C0742985', 'C0019214', 'C0019209', 'C0576456'],
#  'vesalius': ['C0221232'],
#  'mydriatic': ['C0026961'],
#  'unacknowledged': ['C0237154'],
#  'walk': ['C0205254', 'C0085639'],
#  'intoxicated': ['C0728899'],
#  'ascitis': ['C0003962', 'C0019209', 'C0020639', 'C0019079', 'C1313921'],
#  'abo': ['C0427629'],
#  'anguish': ['C0558261', 'C0028084', 'C0233481'],
#  'nonobstructive': ['C0242453'],
#  'macrosomia': ['C0006157', 'C0860096'],
#  'offend': ['C0438696'],
#  'lbnp': ['C0149746', 'C0020578', 'C0020440', 'C0232118'],
#  'overwork': ['C0312422', 'C0917801', 'C0392674'],
#  'apri': ['C0239981'],
#  'spasticity': ['C0030552', 'C0392699', 'C0040822', 'C0233565', 'C0037763'],
#  'bogus': ['C0008301'],
#  'eelv': ['C0020440', 'C0020578', 'C0700292', 'C0232118'],
#  'sleepiness': ['C0037384', 'C0751229', 'C0013144', 'C0917801', 'C0234450'],
#  'woude': ['C0018862'],
#  'signet': ['C0741302'],
#  'unlucky': ['C0847488'],
#  'hopf': ['C0542044'],
#  'thin': ['C0205400'],
#  'cramp': ['C0012833', 'C0030252', 'C0037763', 'C0231528', 'C0220870'],
#  'ripc': ['C0149746'],
#  'expend': ['C0205254'],
#  'hypochlorhydrium': ['C0149696'],
#  'relapse': ['C1517205'],
#  'videofluoroscopy': ['C0038450', 'C0013132'],
#  'interlocked': ['C0542044'],
#  'projectile': ['C0008301'],
#  'musculoskeletal': ['C0024031', 'C0030193', 'C0015672', 'C0036396'],
#  'involvement': ['C0221198'],
#  'mane': ['C0859032'],
#  'photobleach': ['C0231441'],
#  'raising': ['C0872410'],
#  'shutdown': ['C0231187'],
#  'carpometacarpal': ['C0018862'],
#  'electrodiagnosis': ['C0423571', 'C0036396'],
#  'frustration': ['C0233481', 'C1299586'],
#  'epme': ['C0032739'],
#  'child': ['C0497406'],
#  'trapped': ['C0231441'],
#  'fmu': ['C0860096'],
#  'pulmonic': ['C0232118'],
#  'temp': ['C0043144', 'C0008031'],
#  'addiction': ['C0438696'],
#  'pressurization': ['C0020578'],
#  'obstruct': ['C0264576'],
#  'bathing': ['C0016382', 'C0037383', 'C0038990'],
#  'graftons': ['C0233647'],
#  'frc': ['C0425488'],
#  'irritable': ['C0030318', 'C0541992', 'C0015672', 'C0030193', 'C0016204'],
#  'hepatosplenic': ['C0038002', 'C0019214'],
#  'meana': ['C0043144'],
#  'coronary': ['C0002962'],
#  'numbering': ['C0429562'],
#  'saturation': ['C0700292'],
#  'metamyelocyte': ['C0085702'],
#  'isometric': ['C0231530', 'C0427008'],
#  'dtus': ['C0347938'],
#  'neurofunctional': ['C0338656'],
#  'attempter': ['C0438696'],
#  'lev': ['C0036572'],
#  'overlaid': ['C0429562'],
#  'enter': ['C0424092'],
#  'sfv': ['C0016927'],
#  'paronychium': ['C0013491', 'C0033774', 'C0041834', 'C0085624', 'C0241157'],
#  'precooled': ['C0085593'],
#  'endocrinal': ['C0019572', 'C0149696', 'C0235250'],
#  'gun': ['C0008301'],
#  'hemolysis': ['C0020639', 'C0239981'],
#  'stereoview': ['C0429562'],
#  'dysexecutive': ['C0338656', 'C0233565'],
#  'cinca': ['C0003862', 'C0018862'],
#  'phasing': ['C0429562'],
#  'panin': ['C0741302'],
#  'proangiogenic': ['C1269955'],
#  'eyeball': ['C0026961'],
#  'obst': ['C0006157'],
#  'gedvi': ['C0020440'],
#  'woman': ['C0497406', 'C0156543'],
#  'corrugator': ['C0231530'],
#  'saporin': ['C0746619'],
#  'gastropathy': ['C0018932'],
#  'underdiagnosed': ['C0231221', 'C1321756'],
#  'paraesthesia': ['C0030554', 'C0392699', 'C0423571', 'C0028643', 'C0030552'],
#  'ascite': ['C0003962', 'C0038002', 'C0019209', 'C0020639', 'C0239981'],
#  'dysarthric': ['C0013362', 'C0233844', 'C1273573', 'C0233647'],
#  'anxious': ['C0234450', 'C0233481', 'C0030318', 'C0847488'],
#  'csd': ['C0036572'],
#  'canptcphysiotherapy': ['C0024031'],
#  'forced': ['C0013404', 'C0020578'],
#  'stomach': ['C0009806', 'C0016204', 'C0232726'],
#  'hiatal': ['C0018834'],
#  'pernicious': ['C0239981', 'C0020639', 'C0018965', 'C0020621', 'C0019214'],
#  'sideeffect': ['C0559546', 'C1096646'],
#  'supranormal': ['C0578150', 'C0425488'],
#  'sinister': ['C0232267', 'C0018800'],
#  'hdfn': ['C0427629', 'C0860096'],
#  'blunting': ['C0241526', 'C0232498', 'C0872410', 'C0742985', 'C0277845'],
#  'tumble': ['C0231441'],
#  'tetrachoric': ['C0578859'],
#  'pseudocapsule': ['C0241158'],
#  'rhogtpase': ['C1269955'],
#  'ﬁstula': ['C1313921'],
#  'amiodarone': ['C0020461'],
#  'donate': ['C0424092'],
#  'transaminase': ['C1096646', 'C0019209', 'C0239981', 'C0231528', 'C0020621'],
#  'mammographically': ['C0034079', 'C0741302'],
#  'senile': ['C0338656'],
#  'nocturium': ['C0014394', 'C0242453', 'C1291077', 'C0600142', 'C0032617'],
#  'envelope': ['C0016927'],
#  'paraplegic': ['C0024031', 'C0522224', 'C0425251'],
#  'cricopharyngeal': ['C1321756', 'C0038450', 'C0019825', 'C0013362'],
#  'micropapillary': ['C0741302'],
#  'anaesthetics': ['C0030193'],
#  'hypopnea': ['C0037384', 'C0425488', 'C0232602', 'C0700292', 'C0231835'],
#  'fomite': ['C0037383'],
#  'acral': ['C0332573', 'C0041834'],
#  'urolbmc': ['C0242453'],
#  'laxity': ['C0311395'],
#  'paraphilia': ['C0558141', 'C0007398'],
#  'prednisolone': ['C1517205'],
#  'musculoskelet': ['C0024031'],
#  'optimism': ['C0233481'],
#  'hematological': ['C0038002', 'C0020639', 'C0239981', 'C0019209', 'C0019214'],
#  'intimal': ['C0241158'],
#  'constrictive': ['C0232118', 'C0264576'],
#  'disassociate': ['C0424092'],
#  'hypoxemic': ['C0700292', 'C0020578', 'C0020440', 'C0578150', 'C0425488'],
#  'urgency': ['C0042963', 'C1299586', 'C0232602', 'C1291077', 'C0858924'],
#  'strangely': ['C0847488', 'C0558261'],
#  'haematology': ['C0020639', 'C0239981'],
#  'aspergilloma': ['C0034079'],
#  'mouth': ['C0013132', 'C0037383', 'C0019825', 'C0008301', 'C0010200'],
#  'alexium': ['C0233647'],
#  'peristomal': ['C0008767', 'C0013491'],
#  'undocked': ['C0231441'],
#  'slat': ['C0311395'],
#  'masih': ['C0019079'],
#  'tnus': ['C0520887', 'C0520886', 'C0086439'],
#  'soundness': ['C0311395'],
#  'acaid': ['C0241526'],
#  'unreal': ['C0847488'],
#  'carbetocin': ['C0006157'],
#  'lomo': ['C0231530'],
#  'heterozygosity': ['C0281825'],
#  'wonderful': ['C0558261'],
#  'bullying': ['C0438696'],
#  'hyperkeratosis': ['C0241157', 'C0332573', 'C0041834'],
#  'justice': ['C0237154'],
#  'extrauterine': ['C0006157'],
#  'lipohypertrophy': ['C0019572', 'C0332573'],
#  'cva': ['C0085619', 'C0235710', 'C0039070', 'C0008031', 'C0000727'],
#  'zenker': ['C1321756'],
#  'subintimal': ['C0241158'],
#  'eft': ['C0002416'],
#  'dogs': ['C0311395'],
#  'embarrassed': ['C0847488', 'C0558261', 'C0233481'],
#  'electrophysiologic': ['C0231530', 'C0039070', 'C0232201'],
#  'hpb': ['C0003962'],
#  'diagnoses': ['C0007398', 'C0234133', 'C0004604'],
#  'uco': ['C0020578', 'C0020440', 'C0149746', 'C0700292', 'C0006157'],
#  'hypercalcemia': ['C0020621', 'C0020461', 'C0020625', 'C0032617', 'C0020639'],
#  'boo': ['C0242453'],
#  'bronchiectasis': ['C0743482',
#   'C0035508',
#   'C0264576',
#   'C0038450',
#   'C0019079'],
#  'arrhythmium': ['C0039070', 'C0428977', 'C0232201', 'C0020649', 'C0235710'],
#  'premenstrual': ['C0235250', 'C0600142', 'C0019572', 'C0022107', 'C0917801'],
#  'haemorrhagic': ['C0019080', 'C0424749'],
#  'pyomyositis': ['C0003862', 'C0231528'],
#  'neurogenomics': ['C0338656'],
#  'burglary': ['C0237154'],
#  'siadh': ['C0020625', 'C0020461', 'C0020621', 'C0032617', 'C0235250'],
#  'cvcc': ['C0859032', 'C0008301'],
#  'osteophyte': ['C0241158'],
#  'harden': ['C0948786'],
#  'nonsustained': ['C0520886', 'C0520887', 'C0039070', 'C0232201', 'C0235710'],
#  'persons': ['C0237154'],
#  'eater': ['C0020175'],
#  'haptotaxi': ['C1269955'],
#  'cyst': ['C0221198', 'C1313921'],
#  'aidp': ['C0234133'],
#  'bronchopneumonium': ['C0019079',
#   'C0743482',
#   'C0038450',
#   'C0011991',
#   'C0264576'],
#  'spirometric': ['C0425488', 'C0337672', 'C0743482', 'C0232118'],
#  'coitus': ['C1384606', 'C0156543', 'C0013428'],
#  'dystonia': ['C0234133', 'C0040822', 'C0233565', 'C0004134', 'C0013362'],
#  'tokenization': ['C0233647'],
#  'uterine': ['C0006157'],
#  'rewarming': ['C0020578', 'C0149746', 'C0578150'],
#  'stressful': ['C0233481', 'C0438696'],
#  'accid': ['C0008301'],
#  'satiated': ['C0020175'],
#  'targetoid': ['C0332573', 'C0241157', 'C0041834'],
#  'telangiectatic': ['C0332573'],
#  'micromovement': ['C0427008'],
#  'enfuvirtide': ['C0016927'],
#  'tah': ['C0018932'],
#  'somatoform': ['C0030318', 'C0022107'],
#  'tumorassociated': ['C0024103', 'C1269955'],
#  'osa': ['C0037384', 'C0700292', 'C0751229', 'C0039070', 'C0917799'],
#  'fullness': ['C1291077', 'C0581912', 'C0016204', 'C0232726', 'C0858924'],
#  'buysse': ['C0751229'],
#  'ketonurium': ['C0032617', 'C0020639', 'C0239981', 'C0240962', 'C0020621'],
#  'smoking': ['C0337672', 'C0205254', 'C0497406'],
#  'soften': ['C0948786'],
#  'lesterh': ['C0085606'],
#  'ilm': ['C0026961'],
#  'diagnosis': ['C0231221'],
#  'qtcd': ['C0520887'],
#  'axilla': ['C0332573', 'C0041834', 'C0013491', 'C0037580', 'C0332575'],
#  'replicationarch': ['C0030318'],
#  'inmate': ['C0237154'],
#  'hyperbaric': ['C0020578', 'C0700292'],
#  'neurohumoral': ['C0149746'],
#  'dle': ['C0332573', 'C0041834', 'C0241157'],
#  'cavity': ['C0221198'],
#  'anoxia': ['C0020440', 'C0085628', 'C0020578', 'C0028961'],
#  'tortuosity': ['C0427008', 'C0205400'],
#  'scalloping': ['C0205400', 'C0038999'],
#  'mania': ['C0007398', 'C0240805', 'C0022107'],
#  'touching': ['C0008301', 'C0037383', 'C0542073'],
#  'helpless': ['C0847488', 'C0233481'],
#  'chewing': ['C0013132', 'C0149758', 'C0037384'],
#  'dumb': ['C0859032', 'C0558261'],
#  'psychiatrie': ['C0007398'],
#  'jvp': ['C0240100', 'C0085619', 'C0034642', 'C0006318', 'C0018800'],
#  'nonstress': ['C0020578', 'C0235396'],
#  'phosphokinase': ['C0028961', 'C0231528', 'C0020639', 'C0003862', 'C0020621'],
#  'translate': ['C0085639'],
#  'poorly': ['C1299586'],
#  'smear': ['C0032739'],
#  'concerned': ['C0233481', 'C0847488'],
#  'paradigin': ['C0233647'],
#  'endocapillary': ['C0741302'],
#  'tbln': ['C0032739'],
#  'hyperaldosteronism': ['C0032617', 'C0020621', 'C0020461', 'C0020625'],
#  'neurolbmc': ['C0338656', 'C0233565'],
#  'tle': ['C0036572'],
#  'disassemble': ['C0231441'],
#  'knob': ['C0016927'],
#  'fiv': ['C0016927'],
#  'transbronchial': ['C0034079'],
#  'unhealthy': ['C0497406', 'C0205254', 'C0020175'],
#  'incarcerated': ['C0237154', 'C0558141'],
#  'walking': ['C0205254'],
#  'irregularity': ['C0205400'],
#  'intraindividual': ['C0149746'],
#  'severest': ['C0234133'],
#  'cdyn': ['C0020578', 'C0425488'],
#  'regenerated': ['C0241158'],
#  'mephedrone': ['C0728899'],
#  'stature': ['C0019572'],
#  'miscarry': ['C0860096'],
#  'stiffen': ['C0427008'],
#  'abobotulinumtoxina': ['C0392699'],
#  'hpca': ['C0024103'],
#  'uncoordinated': ['C0242143', 'C0233844', 'C0009024'],
#  'yellowish': ['C0443260', 'C0241157'],
#  'intercurrent': ['C0742985', 'C1096646', 'C0020639', 'C0000727', 'C0004093'],
#  'osteopathy': ['C0036396', 'C0024031'],
#  'kindling': ['C0036572'],
#  'tethered': ['C0231441'],
#  'audiogenic': ['C0036572'],
#  'ovulation': ['C0156543'],
#  'sporadic': ['C0004134'],
#  'contraceptive': ['C0239301', 'C0156543'],
#  'cystotomy': ['C1313921'],
#  'smooth': ['C0427008', 'C0205400'],
#  'crusting': ['C0241157', 'C0013491', 'C0041834', 'C0085624', 'C0332575'],
#  'ptz': ['C0036572'],
#  'matrilysin': ['C1269955'],
#  'bolder': ['C0424337'],
#  'rabbit': ['C0746619'],
#  'fantastic': ['C0558261'],
#  'plethysmographic': ['C0232118', 'C0425488', 'C0020578'],
#  'hypoxaemia': ['C0700292', 'C0020578', 'C0020440', 'C0038450', 'C0232118'],
#  'nasalance': ['C0231890'],
#  'locomote': ['C0231441'],
#  'edh': ['C0019080'],
#  'holep': ['C0242453'],
#  'leukostasis': ['C0085702'],
#  'anthracosis': ['C0743482', 'C0034079', 'C0019079', 'C0035508'],
#  'retrosternal': ['C0008031', 'C0235710', 'C0030252', 'C0038450', 'C0085619'],
#  'pegboard': ['C0233844', 'C0233565'],
#  'placing': ['C0277845'],
#  'histotype': ['C0741302'],
#  'amepre': ['C0205254'],
#  'mesor': ['C0751229'],
#  'dermatolanais': ['C0041834'],
#  'plasmocyte': ['C0741302'],
#  'asana': ['C0149746', 'C0872410'],
#  'callus': ['C0241158'],
#  'anoxium': ['C0020440', 'C0235396'],
#  'antidote': ['C0728899'],
#  'compulsion': ['C0233492', 'C0424337', 'C0233481'],
#  'eruption': ['C0041834', 'C0038999', 'C0332573', 'C0241157'],
#  'jagust': ['C0347938'],
#  'pab': ['C0746619'],
#  'mcallister': ['C0554980'],
#  'feno': ['C0337672'],
#  'response': ['C0241526'],
#  'lqts': ['C0039070', 'C0520887'],
#  'promyelocyte': ['C0085702'],
#  'pearsons': ['C0578859', 'C0344315'],
#  'poma': ['C0871754'],
#  'cytopathological': ['C0741302'],
#  'eave': ['C0558261'],
#  'virchow': ['C0221232'],
#  'pabc': ['C0860096'],
#  'tsst': ['C0020578'],
#  'trichobezoar': ['C0149696', 'C1321756', 'C0232726'],
#  'traumatize': ['C0438696'],
#  'infracted': ['C0241158'],
#  'whz': ['C0041667'],
#  'aperiodic': ['C0542044'],
#  'intromission': ['C1384606'],
#  'streak': ['C0241157', 'C0205400'],
#  'lability': ['C0424230', 'C0022107', 'C0231230', 'C0872410', 'C0085631'],
#  'electroconvulsive': ['C0040264'],
#  'urticarial': ['C0041834', 'C0033774', 'C0085624', 'C0241157', 'C0332573'],
#  'calve': ['C0311395'],
#  'dieting': ['C0020175', 'C0043094', 'C0497406'],
#  'throb': ['C0751466', 'C0085636', 'C0030554', 'C0423571', 'C0220870'],
#  'cram': ['C0859032'],
#  'pigs': ['C1260880'],
#  'villain': ['C0558261'],
#  'anaemic': ['C0239981', 'C0020639'],
#  'irritation': ['C0677500', 'C0085624', 'C0016382', 'C0033774', 'C0332575'],
#  'wootton': ['C0554980'],
#  'recreationally': ['C0205254'],
#  'paraphernalia': ['C0237154'],
#  'tolvaptan': ['C0020461'],
#  'capsaicin': ['C0677500'],
#  'desynchrony': ['C0751229', 'C0149746'],
#  'recoil': ['C0427008'],
#  'proteinuria': ['C0018965', 'C0239981', 'C0020639', 'C0028961', 'C0020461'],
#  'codification': ['C0233647'],
#  'antineutrophil': ['C0018965'],
#  'perinephric': ['C1313921'],
#  'hebrew': ['C0233647'],
#  'evlwi': ['C0020440', 'C0700292', 'C0425488'],
#  'sensibility': ['C0231890', 'C0231230', 'C0030552'],
#  'peyronie': ['C0242453'],
#  'subjectivity': ['C1299586'],
#  'erkrankungen': ['C0221232'],
#  'auditory': ['C0040264', 'C0034880'],
#  'psychosomatic': ['C0030318'],
#  'aed': ['C0036572'],
#  'auris': ['C0038450'],
#  'steatorrhea': ['C0149696', 'C0016204', 'C1291077', 'C0032617', 'C0009806'],
#  'nonsurvivor': ['C0578150'],
#  'narcolepsy': ['C0917799', 'C0751229', 'C1321756'],
#  'cephalic': ['C0006157'],
#  'inflation': ['C0020578'],
#  'gi': ['C0018932', 'C0009806', 'C0232726', 'C0008031', 'C0000737'],
#  'microalbumin': ['C0239981'],
#  'pentylenetetrazol': ['C0036572'],
#  'vcd': ['C0026961'],
#  'postop': ['C0018932'],
#  'liberation': ['C0728899'],
#  'schizoaffective': ['C0030318'],
#  'intrusive': ['C0028084', 'C0233481'],
#  'ijo': ['C0497406', 'C0205254'],
#  'veteran': ['C0237154'],
#  'pnc': ['C0860096'],
#  'inescapable': ['C0028084'],
#  'alveolarization': ['C0743482', 'C0700292', 'C0020440'],
#  'lie': ['C0085639'],
#  'vgb': ['C0036572'],
#  'bleuler': ['C0007398'],
#  'reoxygenation': ['C0020578', 'C0020440'],
#  'ritualistic': ['C0016579', 'C0424230', 'C0872410'],
#  'ftv': ['C0149746'],
#  'chondrocalcinosis': ['C0018862'],
#  'pd': ['C0233565', 'C0234133', 'C0040822', 'C0338656'],
#  'rheumatological': ['C0003862'],
#  'lady': ['C0030252', 'C0392680', 'C0037580', 'C0231218', 'C1273573'],
#  'hematurium': ['C0018965', 'C0232726', 'C0013428', 'C0019079', 'C0232498'],
#  'joint': ['C0311395'],
#  'xerostomium': ['C0019825', 'C0013132', 'C0033774', 'C0677500', 'C0085624'],
#  'merrf': ['C0004134', 'C0234133', 'C0018991'],
#  'nephrocalcinosis': ['C0020621', 'C0032617', 'C0020461', 'C0020625'],
#  'myoﬁbroblasts': ['C0241158'],
#  'auscultatory': ['C0240100', 'C0232118', 'C0438716', 'C0034642'],
#  'obsessive': ['C0030318'],
#  'hematemesis': ['C0232726', 'C0235710', 'C0018965', 'C0019079', 'C0220870'],
#  'mepp': ['C0231530'],
#  'csq': ['C0004604'],
#  'pectori': ['C0002962', 'C0235710', 'C0008031', 'C0004604', 'C0030252'],
#  'sufficiency': ['C0020175'],
#  'reoccurrence': ['C0742985', 'C0231187', 'C0008767', 'C1517205'],
#  'anxietyj': ['C0030318'],
#  'bad': ['C0847488', 'C0233481', 'C0233492'],
#  'pfv': ['C0016927'],
#  'nssus': ['C0438696'],
#  'vasectomy': ['C0156543'],
#  'gxt': ['C0392674'],
#  'persistant': ['C1096646', 'C0018932', 'C0018965', 'C0239981', 'C0576456'],
#  'dysphasium': ['C0013362', 'C1273573', 'C0233844', 'C0030552', 'C0030554'],
#  'adenopathy': ['C0038002', 'C0232498', 'C0019214', 'C0019079', 'C0034079'],
#  'hyperkinetic': ['C0917799', 'C0234133', 'C0007398', 'C0233565', 'C0085628'],
#  'haematurium': ['C0018965', 'C0013428', 'C0232726', 'C0232498', 'C1313921'],
#  'nibble': ['C0037383', 'C0311395', 'C0085624'],
#  'porphyrium': ['C0020621'],
#  'tinted': ['C0085635'],
#  'sydenham': ['C0007398', 'C0234133', 'C0240805', 'C0030552'],
#  'halitosis': ['C0013132', 'C0149758', 'C0085624', 'C0677500'],
#  'labouring': ['C0006157', 'C0860096'],
#  'gassing': ['C0312422'],
#  'moduli': ['C0427008'],
#  'mtwa': ['C0520887', 'C0232201', 'C0039070', 'C0520886'],
#  'nonatopic': ['C0337672'],
#  'clinically': ['C0231221', 'C0221198', 'C0559546', 'C0020649'],
#  'mediocre': ['C0847488'],
#  'mastalgium': ['C0600142', 'C0019572', 'C1384606', 'C1291077', 'C0232726'],
#  'dream': ['C0028084'],
#  'protuberant': ['C0000731', 'C0030232', 'C0019214'],
#  'ahi': ['C0037384', 'C0700292', 'C0751229', 'C0425488', 'C0020578'],
#  'anesthesiology': ['C0020649', 'C0030193'],
#  'cffdna': ['C0427629'],
#  'phonetically': ['C0233647'],
#  'nomid': ['C0018862'],
#  'semiovale': ['C0347938'],
#  'forehead': ['C0332573'],
#  'siren': ['C0028084'],
#  ...}

# %%
ser = pd.Series(new_dic)
df = pd.DataFrame(ser)

# %%
df
# Out:
#                                                                     0
# aabr                                                       [C0034880]
# aadjust                                                    [C0239301]
# aasi                                                       [C0149746]
# aasm                [C0037384, C0425488, C0751229, C0232602, C0039...
# aatd                                                       [C0743482]
# ab                                                         [C0746619]
# abcess                                           [C1313921, C0019080]
# abdom                                                      [C0034079]
# abdomen                                [C0740844, C0000731, C0232498]
# abdomina                                                   [C1313921]
# abdominal                              [C0000737, C0000731, C0232498]
# abdominopelvic                                   [C1313921, C0740844]
# abducen                                [C0030552, C0013362, C0234133]
# abg                                    [C0700292, C0578150, C0028961]
# abga                [C0700292, C0020578, C0425488, C0232118, C0231...
# ability                                                    [C1299586]
# abnormal                               [C0019209, C0205400, C0030232]
# abnormality         [C0221198, C0205400, C0231187, C0019209, C0004...
# abnormally                                       [C0424230, C0205400]
# abo                                                        [C0427629]
# abobotulinumtoxina                                         [C0392699]
# abolishment                                                [C0241526]
# abomasal                                         [C0016204, C0232726]
# abomasum                                                   [C0000731]
# abort                                                      [C0424092]
# aborted                                                    [C0156543]
# abp                                                        [C0149746]
# abpi                                             [C0006318, C0240100]
# abpm                                                       [C0149746]
# abr                                              [C0034880, C0040264]
# ...                                                               ...
# zygapophysial                                    [C0036396, C0024031]
# zygomaticus                                                [C0231530]
# zygosity                                                   [C0427629]
# ﬁbers                                                      [C0241158]
# ﬁbrillation                                      [C0039070, C0002962]
# ﬁbrin                                                      [C0241158]
# ﬁbromatosis                                                [C0221198]
# ﬁbrosis                                          [C0743482, C0205400]
# ﬁbrotic                                                    [C0241158]
# ﬁbrous                                           [C0241158, C0205400]
# ﬁctive                                 [C0231530, C0872410, C0040822]
# ﬁde                                                        [C0030232]
# ﬁller                                                      [C0233647]
# ﬁnasteride                                                 [C0239301]
# ﬁom                                                        [C0859032]
# ﬁst                                                        [C0872410]
# ﬁstula                                                     [C1313921]
# ﬁxating                                                    [C0085635]
# ﬂaccid              [C0030552, C0009024, C0242143, C0085628, C0234...
# ﬂare                [C1517205, C0033774, C0085624, C0677500, C0423...
# ﬂares               [C1517205, C1096646, C0003862, C0033774, C0231...
# ﬂaw                                                        [C0859032]
# ﬂaws                                                       [C1299586]
# ﬂee                                                        [C0859032]
# ﬂick                                             [C0009024, C0423571]
# ﬂoating                                                    [C0231441]
# ﬂow                                                        [C0438716]
# ﬂuency                                                     [C0233647]
# ﬂushing                                                    [C0016382]
# ﬂutter              [C0039070, C0006318, C0231530, C0240100, C0428...
#
# [8195 rows x 1 columns]

# %%
df.to_csv('Dictionary2.csv', header = False)

# %%
len(new_dic)
# Out:
# 8195
